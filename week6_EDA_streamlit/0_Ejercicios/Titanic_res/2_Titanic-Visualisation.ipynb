# %% [markdown]
#    #                                                  Titanic Exercise II
#    #### Practice matplotlib & seaborn

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# 1. Read the `.csv` file you generated in **1_Titanic-Pandas** `titanic_cleaned.csv` and call the variable `titanic`.
#
# Help: If you didn't get to the point in which you should have saved the file, ask the instructor.

# %%
titanic = pd.read_csv("data/titanic_cleaned.csv")

# %%
titanic.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name  gender    age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                   Allison, Master. Hudson Trevor    male   0.92      1
# 2                     Allison, Miss. Helen Loraine  female   2.00      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      2  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
titanic.drop("Unnamed: 0", axis = 1, inplace = True)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 2. Using matplotlib find the appropriate visualization to show the distribution of the column `age`

# %%
plt.hist(titanic["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3. Now use seaborn to show the distribution of the column `age`.

# %%
sns.distplot(titanic["age"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# 4. Use subplots to plot the distribution of the Age variable with bins equal to 10, 20 and 50.
#
# Use `sns.histplot()` for that aim.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True)

sns.histplot(titanic["age"], bins = 10, ax = ax1)
sns.histplot(titanic["age"], bins = 20, ax = ax2)
sns.histplot(titanic["age"], bins = 50, ax = ax3)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# 5. Whether the bin size affects your plot? Why?

# %%
# The less bins you have, the more the data is grouped. So, for some cases it might be good to have less bins to have a better look at the overall trends, whereas in other cases you might want to see the data more in detail.

# %% [markdown]
# 6. Using matplotlib find the appropriate plot to visualize the column `'gender'`

# %%
y_ax = titanic["gender"].value_counts().values
x_ax = titanic["gender"].value_counts().index

# %%
plt.bar(x_ax, y_ax, color = ["blue", "red"])

plt.title("Women and men in the titanic")
# Out:
# Text(0.5, 1.0, 'Women and men in the titanic')

# %% [markdown]
# 7. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?

# %%
sns.countplot(x = "gender", data = titanic)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# 6. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %%
sns.catplot(x = "gender", y = "survived", data = titanic, kind = "bar")

# %% [markdown]
# 7. Use the appropriate plot to visualize the column `pclass`.

# %%
sns.catplot(x = "pclass", data = titanic, kind = "count")

# %% [markdown]
# 8. We would like to have in one single plot the summary statistics of the feature `age`. Choose the appropriate plot to show below.

# %%
# Como no estoy seguro de a qué os referís, hice 2 versiones

# %%
# 1) simplemente grafico los estadísticos (sin contar con count, porque entonces no se ve nada a parte de eso)

# %%
age_vals = titanic["age"].describe().values[1:]
age_inds = titanic["age"].describe().index[1:]
age_inds
# Out:
# Index(['mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
sns.catplot(x = age_inds, y = age_vals, data = titanic, kind = "bar", annot )
# Out:
#   File "<ipython-input-17-d41bb229a60e>", line 1
#     sns.catplot(x = age_inds, y = age_vals, data = titanic, kind = "bar", annot )
#                                                                          ^
# SyntaxError: positional argument follows keyword argument

# %%
# 2) Hago un boxplot que no me da todo, pero si los quartiles, mediana, e IQR

# %%
sns.boxplot(titanic["age"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# 9. What does the previous plot tell you about the feature Age? Comment.

# %%
# 1- Hay una gran dispersión. Es decir, hay gente muy joven y muy mayor
# 2- La mayoría se concentra entre 20 y 40 años, siendo la mitad de los pasajeros <= 28 (aprox)
# 3- Tenemos unos cuantos outliers que están por encima de los 67 (aprox)
# 4- La distribución está sesgada hacia la derecha
# 5- Como la dispersión es relativamente alta, probablemente la mediana sea una mejor medida de centro que la media

# %% [markdown]
# 10. Now in addition to the summary statistics, we also want to visualize the distribution of `age`. Choose the appropriate plot to show below.

# %%
sns.distplot(titanic["age"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# 11. Use the appropriate plot to display the distributions of `age` in relation to `gender`.
#
# Hint: use Facetgrid to display the distribution of age for each categorical value of gender.

# %%
titanic[["age", "gender"]].head()
# Out:
#      age  gender
# 0  29.00  female
# 1   0.92    male
# 2   2.00  female
# 3  30.00    male
# 4  25.00  female

# %%
g = sns.FacetGrid(titanic, col = "gender")
g.map_dataframe(sns.histplot, x = "age")

# %% [markdown]
# 12. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %%
titanic[titanic["survived"] == 0].head()
# Out:
#    pclass  survived                                             name  gender  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 2   2.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 7  39.0      0      0    112050    0.0000      A36        S  NaN    NaN
# 9  71.0      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                          home.dest
# ...

# %%
sns.kdeplot(data = titanic, x = "age", hue = "survived", fill = True, common_norm = False, alpha = .5, shade = True, label = ["Survived", "didn't"], color = ["red", "green"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data = titanic[titanic["survived"] == 0], x = "age", fill = True, color = "red", label = "Didn't survive", shade = True)
sns.kdeplot(data = titanic[titanic["survived"] == 1], x = "age", fill = True, color = "green", label = "Survived", shade = True)
plt.legend()

# %%
#your code

# %% [markdown]
# 13. Using Seaborn plot the correlation matrix of various features.
#
# Hint: search how to use `heatmap`

# %%
corr = titanic.corr()
corr
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055512 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055512  1.000000 -0.243699 -0.150917  0.178740  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178740  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, square = True, annot = True, linewidths = .3, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 14. According to the previous plot, what are the most correlated feature? Comment.

# %%
# age and pclass are negatively correlated (-0.41)
# survived and pclass are also negatively correlated (-0.31)
# and for positive correlations we have parch and sibsp
