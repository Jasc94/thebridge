# %%
# Import libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import re
from varname import nameof

# %%
nutrition = pd.read_csv("../data/Nutritional_values.csv")
nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %%
# I can see already some missing values
# Let's do some checking

# %%
# Shape
nutrition.shape
# Out:
# (8789, 77)

# %%
nutrition.columns
# Out:
# Index(['Unnamed: 0', 'name', 'serving_size', 'calories', 'total_fat',
#        'saturated_fat', 'cholesterol', 'sodium', 'choline', 'folate',
#        'folic_acid', 'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin',
#        'vitamin_a', 'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
for column, missing in nutrition.isnull().sum().iteritems():
    if missing > 0:
        print(f"Food property: {column}\nMissing values: {missing}")
        print('-' * 50)
# Out:
# Food property: saturated_fat
# Missing values: 1590
# --------------------------------------------------

# %%
# Well, I'm only missing values for the "saturated_fat" column.
# I could simply drop that column, although it is very interesting from a nutritional standpoint. I'll keep it at the moment to see if I can still take some advantage of it

# %%
# Next, I want to check if the serving size is the same for all the food. Otherwise, comparison wouldn't be reliable
nutrition["serving_size"].unique()
# Out:
# array(['100 g'], dtype=object)

# %%
# This also looks fine

# %%
# Let's have a look at the data types
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                7199 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
#  13  riboflavin                   8789 non-null   object
#  14  thiamin                      8789 non-null   object
#  15  vitamin_a                    8789 non-null   object
#  16  vitamin_a_rae                8789 non-null   object
#  17  carotene_alpha               8789 non-null   object
#  18  carotene_beta                8789 non-null   object
#  19  cryptoxanthin_beta           8789 non-null   object
#  20  lutein_zeaxanthin            8789 non-null   object
#  21  lucopene                     8789 non-null   int64
#  22  vitamin_b12                  8789 non-null   object
#  23  vitamin_b6                   8789 non-null   object
#  24  vitamin_c                    8789 non-null   object
#  25  vitamin_d                    8789 non-null   object
#  26  vitamin_e                    8789 non-null   object
#  27  tocopherol_alpha             8789 non-null   object
#  28  vitamin_k                    8789 non-null   object
#  29  calcium                      8789 non-null   object
#  30  copper                       8789 non-null   object
#  31  irom                         8789 non-null   object
#  32  magnesium                    8789 non-null   object
#  33  manganese                    8789 non-null   object
#  34  phosphorous                  8789 non-null   object
#  35  potassium                    8789 non-null   object
#  36  selenium                     8789 non-null   object
#  37  zink                         8789 non-null   object
#  38  protein                      8789 non-null   object
#  39  alanine                      8789 non-null   object
#  40  arginine                     8789 non-null   object
#  41  aspartic_acid                8789 non-null   object
#  42  cystine                      8789 non-null   object
#  43  glutamic_acid                8789 non-null   object
#  44  glycine                      8789 non-null   object
#  45  histidine                    8789 non-null   object
#  46  hydroxyproline               8789 non-null   object
#  47  isoleucine                   8789 non-null   object
#  48  leucine                      8789 non-null   object
#  49  lysine                       8789 non-null   object
#  50  methionine                   8789 non-null   object
#  51  phenylalanine                8789 non-null   object
#  52  proline                      8789 non-null   object
#  53  serine                       8789 non-null   object
#  54  threonine                    8789 non-null   object
#  55  tryptophan                   8789 non-null   object
#  56  tyrosine                     8789 non-null   object
#  57  valine                       8789 non-null   object
#  58  carbohydrate                 8789 non-null   object
#  59  fiber                        8789 non-null   object
#  60  sugars                       8789 non-null   object
#  61  fructose                     8789 non-null   object
#  62  galactose                    8789 non-null   object
#  63  glucose                      8789 non-null   object
#  64  lactose                      8789 non-null   object
#  65  maltose                      8789 non-null   object
#  66  sucrose                      8789 non-null   object
#  67  fat                          8789 non-null   object
#  68  saturated_fatty_acids        8789 non-null   object
#  69  monounsaturated_fatty_acids  8789 non-null   object
#  70  polyunsaturated_fatty_acids  8789 non-null   object
#  71  fatty_acids_total_trans      8789 non-null   object
#  72  alcohol                      8789 non-null   object
#  73  ash                          8789 non-null   object
#  74  caffeine                     8789 non-null   object
#  75  theobromine                  8789 non-null   object
#  76  water                        8789 non-null   object
# dtypes: int64(3), object(74)
# memory usage: 5.2+ MB

# %%
# Well, surprise surprise, most of the column values are objects. Pain in the ass.
# It does make sense though, as many of the columns have the "mg" or "g" appended at the end

# Let's solve this using regex

# %%
# This regex looks fine
s = '0.00 mg'
re.match(r'[\d]*[\.\d]*', s)[0]
# Out:
# '0.00'

# %%
# Let's do some testing
# test = pd.DataFrame(index = nutrition.index)
# test["test"] = nutrition["saturated_fat"].map(lambda x: re.match(r'[\d]*[\.\d]*', x)[0])
# test

# %%
def num_cleaning(x):
    try:
        return re.match(r'[\d]*[\.\d]*', x)[0]
    except:
        return x

# %%
nutrition.set_index("name", inplace = True)

nutrition2 = pd.DataFrame(index = nutrition.index)

for column in nutrition.columns[2:]:
    if nutrition[column].dtype == "O":
        try:
            nutrition2[column] = nutrition[column].map(num_cleaning)
            print(column, "| success!!!")
        except:
            nutrition2[column] = nutrition[column]
            print(column, "| failed---")

nutrition2.head()
# Out:
# total_fat | success!!!
# saturated_fat | success!!!
# cholesterol | success!!!
# sodium | success!!!
# choline | success!!!
# folate | success!!!
# folic_acid | success!!!
# niacin | success!!!
# pantothenic_acid | success!!!
# riboflavin | success!!!
# thiamin | success!!!
# vitamin_a | success!!!
# vitamin_a_rae | success!!!
# carotene_alpha | success!!!
# carotene_beta | success!!!
# cryptoxanthin_beta | success!!!
# lutein_zeaxanthin | success!!!
# vitamin_b12 | success!!!
# vitamin_b6 | success!!!
# vitamin_c | success!!!
# vitamin_d | success!!!
# vitamin_e | success!!!
# tocopherol_alpha | success!!!
# vitamin_k | success!!!
# calcium | success!!!
# copper | success!!!
# irom | success!!!
# magnesium | success!!!
# manganese | success!!!
# phosphorous | success!!!
# potassium | success!!!
# selenium | success!!!
# zink | success!!!
# protein | success!!!
# alanine | success!!!
# arginine | success!!!
# aspartic_acid | success!!!
# cystine | success!!!
# glutamic_acid | success!!!
# glycine | success!!!
# histidine | success!!!
# hydroxyproline | success!!!
# isoleucine | success!!!
# leucine | success!!!
# lysine | success!!!
# methionine | success!!!
# phenylalanine | success!!!
# proline | success!!!
# serine | success!!!
# threonine | success!!!
# tryptophan | success!!!
# tyrosine | success!!!
# valine | success!!!
# carbohydrate | success!!!
# fiber | success!!!
# sugars | success!!!
# fructose | success!!!
# galactose | success!!!
# glucose | success!!!
# lactose | success!!!
# maltose | success!!!
# sucrose | success!!!
# fat | success!!!
# saturated_fatty_acids | success!!!
# monounsaturated_fatty_acids | success!!!
# polyunsaturated_fatty_acids | success!!!
# fatty_acids_total_trans | success!!!
# alcohol | success!!!
# ash | success!!!
# caffeine | success!!!
# theobromine | success!!!
# water | success!!!
#                 total_fat saturated_fat cholesterol sodium choline folate  \
# name
# Cornstarch            0.1           NaN           0   9.00     0.4   0.00
# Nuts, pecans           72           6.2           0   0.00    40.5  22.00
# Eggplant, raw         0.2           NaN           0   2.00     6.9  22.00
# Teff, uncooked        2.4           0.4           0  12.00    13.1      0
# Sherbet, orange         2           1.2           1  46.00     7.7   4.00
#
#                 folic_acid niacin pantothenic_acid riboflavin  ...    fat  \
# name                                                           ...
# Cornstarch            0.00  0.000            0.000      0.000  ...   0.05
# Nuts, pecans          0.00  1.167            0.863      0.130  ...  71.97
# Eggplant, raw         0.00  0.649            0.281      0.037  ...   0.18
# Teff, uncooked           0  3.363            0.942      0.270  ...   2.38
# Sherbet, orange       0.00  0.063            0.224      0.097  ...   2.00
#
#                 saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Cornstarch                      0.009                       0.016
# Nuts, pecans                    6.180                      40.801
# Eggplant, raw                   0.034                       0.016
# Teff, uncooked                  0.449                       0.589
# Sherbet, orange                 1.160                       0.530
#
#                 polyunsaturated_fatty_acids fatty_acids_total_trans alcohol  \
# name
# Cornstarch                            0.025                    0.00     0.0
# Nuts, pecans                         21.614                    0.00     0.0
# Eggplant, raw                         0.076                    0.00     0.0
# Teff, uncooked                        1.071                       0       0
# Sherbet, orange                       0.080                    1.00     0.0
#
#                   ash caffeine theobromine  water
# name
# Cornstarch       0.09     0.00        0.00   8.32
# Nuts, pecans     1.49     0.00        0.00   3.52
# Eggplant, raw    0.66     0.00        0.00  92.30
# Teff, uncooked   2.37        0           0   8.82
# Sherbet, orange  0.40     0.00        0.00  66.10
#
# [5 rows x 72 columns]

# %%
nutrition2.saturated_fat
# Out:
# name
# Cornstarch                                                                                            NaN
# Nuts, pecans                                                                                          6.2
# Eggplant, raw                                                                                         NaN
# Teff, uncooked                                                                                        0.4
# Sherbet, orange                                                                                       1.2
#                                                                                                      ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    1.4
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    3.9
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand     12
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round    1.1
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round    1.1
# Name: saturated_fat, Length: 8789, dtype: object

# %%
# Now, let's transform the object data into numeric one

def to_float(x):
    try:
        return float(x)
    except:
        return x

# %%
nutrition3 = nutrition2.applymap(to_float)
nutrition3.head()
# Out:
#                  total_fat  saturated_fat  cholesterol  sodium  choline  \
# name
# Cornstarch             0.1            NaN          0.0     9.0      0.4
# Nuts, pecans          72.0            6.2          0.0     0.0     40.5
# Eggplant, raw          0.2            NaN          0.0     2.0      6.9
# Teff, uncooked         2.4            0.4          0.0    12.0     13.1
# Sherbet, orange        2.0            1.2          1.0    46.0      7.7
#
#                  folate  folic_acid  niacin  pantothenic_acid  riboflavin  \
# name
# Cornstarch          0.0         0.0   0.000             0.000       0.000
# Nuts, pecans       22.0         0.0   1.167             0.863       0.130
# Eggplant, raw      22.0         0.0   0.649             0.281       0.037
# Teff, uncooked      0.0         0.0   3.363             0.942       0.270
# Sherbet, orange     4.0         0.0   0.063             0.224       0.097
#
#                  ...    fat  saturated_fatty_acids  \
# name             ...
# Cornstarch       ...   0.05                  0.009
# Nuts, pecans     ...  71.97                  6.180
# Eggplant, raw    ...   0.18                  0.034
# Teff, uncooked   ...   2.38                  0.449
# Sherbet, orange  ...   2.00                  1.160
#
#                  monounsaturated_fatty_acids  polyunsaturated_fatty_acids  \
# name
# Cornstarch                             0.016                        0.025
# Nuts, pecans                          40.801                       21.614
# Eggplant, raw                          0.016                        0.076
# Teff, uncooked                         0.589                        1.071
# Sherbet, orange                        0.530                        0.080
#
#                  fatty_acids_total_trans  alcohol   ash  caffeine  \
# name
# Cornstarch                           0.0      0.0  0.09       0.0
# Nuts, pecans                         0.0      0.0  1.49       0.0
# Eggplant, raw                        0.0      0.0  0.66       0.0
# Teff, uncooked                       0.0      0.0  2.37       0.0
# Sherbet, orange                      1.0      0.0  0.40       0.0
#
#                  theobromine  water
# name
# Cornstarch               0.0   8.32
# Nuts, pecans             0.0   3.52
# Eggplant, raw            0.0  92.30
# Teff, uncooked           0.0   8.82
# Sherbet, orange          0.0  66.10
#
# [5 rows x 72 columns]

# %%
nutrition3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Data columns (total 72 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_fat                    8789 non-null   float64
#  1   saturated_fat                7199 non-null   float64
#  2   cholesterol                  8789 non-null   float64
#  3   sodium                       8789 non-null   float64
#  4   choline                      8789 non-null   float64
#  5   folate                       8789 non-null   float64
#  6   folic_acid                   8789 non-null   float64
#  7   niacin                       8789 non-null   float64
#  8   pantothenic_acid             8789 non-null   float64
#  9   riboflavin                   8789 non-null   float64
#  10  thiamin                      8789 non-null   float64
#  11  vitamin_a                    8789 non-null   float64
#  12  vitamin_a_rae                8789 non-null   float64
#  13  carotene_alpha               8789 non-null   float64
#  14  carotene_beta                8789 non-null   float64
#  15  cryptoxanthin_beta           8789 non-null   float64
#  16  lutein_zeaxanthin            8789 non-null   float64
#  17  vitamin_b12                  8789 non-null   float64
#  18  vitamin_b6                   8789 non-null   float64
#  19  vitamin_c                    8789 non-null   float64
#  20  vitamin_d                    8789 non-null   float64
#  21  vitamin_e                    8789 non-null   float64
#  22  tocopherol_alpha             8789 non-null   float64
#  23  vitamin_k                    8789 non-null   float64
#  24  calcium                      8789 non-null   float64
#  25  copper                       8789 non-null   float64
#  26  irom                         8789 non-null   float64
#  27  magnesium                    8789 non-null   float64
#  28  manganese                    8789 non-null   float64
#  29  phosphorous                  8789 non-null   float64
#  30  potassium                    8789 non-null   float64
#  31  selenium                     8789 non-null   float64
#  32  zink                         8789 non-null   float64
#  33  protein                      8789 non-null   float64
#  34  alanine                      8789 non-null   float64
#  35  arginine                     8789 non-null   float64
#  36  aspartic_acid                8789 non-null   float64
#  37  cystine                      8789 non-null   float64
#  38  glutamic_acid                8789 non-null   float64
#  39  glycine                      8789 non-null   float64
#  40  histidine                    8789 non-null   float64
#  41  hydroxyproline               8789 non-null   float64
#  42  isoleucine                   8789 non-null   float64
#  43  leucine                      8789 non-null   float64
#  44  lysine                       8789 non-null   float64
#  45  methionine                   8789 non-null   float64
#  46  phenylalanine                8789 non-null   float64
#  47  proline                      8789 non-null   float64
#  48  serine                       8789 non-null   float64
#  49  threonine                    8789 non-null   float64
#  50  tryptophan                   8789 non-null   float64
#  51  tyrosine                     8789 non-null   float64
#  52  valine                       8789 non-null   float64
#  53  carbohydrate                 8789 non-null   float64
#  54  fiber                        8789 non-null   float64
#  55  sugars                       8789 non-null   float64
#  56  fructose                     8789 non-null   float64
#  57  galactose                    8789 non-null   float64
#  58  glucose                      8789 non-null   float64
#  59  lactose                      8789 non-null   float64
#  60  maltose                      8789 non-null   float64
#  61  sucrose                      8789 non-null   float64
#  62  fat                          8789 non-null   float64
#  63  saturated_fatty_acids        8789 non-null   float64
#  64  monounsaturated_fatty_acids  8789 non-null   float64
#  65  polyunsaturated_fatty_acids  8789 non-null   float64
#  66  fatty_acids_total_trans      8789 non-null   float64
#  67  alcohol                      8789 non-null   float64
#  68  ash                          8789 non-null   float64
#  69  caffeine                     8789 non-null   float64
#  70  theobromine                  8789 non-null   float64
#  71  water                        8789 non-null   float64
# dtypes: float64(72)
# memory usage: 5.1+ MB

# %%
macros = ["protein", "carbohydrate", "fat", "alcohol"]
micros = ["vitamin_a", "vitamin_b12", "vitamin_b6", "vitamin_c", "vitamin_e", "magnesium", "zinc", "calcium", "irom", "potassium"]
others = ["fiber", "sugars", "cholesterol"]
fats = ["total_fat", "saturated_fat", "saturated_fatty_acids", "monounsaturated_fatty_acids", "polyunsaturated_fatty_acids"]

# %%
# After reading the documentation, I think that some of these columns could be full of 0s, so I'll just drop those if that's the case

# %%
nutrition3_stats = nutrition3.describe().T
nutrition3_stats
# Out:
#                 count        mean         std  min    25%    50%     75%  \
# total_fat      8789.0   10.556855   15.818247  0.0   1.00   5.10   14.00
# saturated_fat  7199.0    4.192791    6.877009  0.1   0.70   2.20    5.00
# cholesterol    8789.0   38.723063  117.358944  0.0   0.00   2.00   65.00
# sodium         8789.0  306.353851  939.220468  0.0  36.00  84.00  396.00
# choline        8789.0   23.681249   51.332265  0.0   0.00   1.60   29.40
# ...               ...         ...         ...  ...    ...    ...     ...
# alcohol        8789.0    0.117522    1.600127  0.0   0.00   0.00    0.00
# ash            8789.0    1.717408    2.967751  0.0   0.77   1.17    2.02
# caffeine       8789.0    2.608829   82.070233  0.0   0.00   0.00    0.00
# theobromine    8789.0    4.695642   60.962608  0.0   0.00   0.00    0.00
# water          8789.0   54.112074   30.772999  0.0  29.70  63.08   77.96
#
#                    max
# total_fat        100.0
# saturated_fat     96.0
# cholesterol     3100.0
# sodium         38758.0
# choline         2403.3
# ...                ...
# alcohol           42.5
# ash               99.8
# caffeine        5714.0
# theobromine     2634.0
# water            100.0
#
# [72 rows x 8 columns]

# %%
nutrition3_stats[nutrition3_stats["mean"] < 0.1]
# Out:
#                  count      mean       std  min  25%    50%   75%    max
# hydroxyproline  8789.0  0.025559  0.077800  0.0  0.0  0.000  0.00   1.13
# tryptophan      8789.0  0.095344  0.127419  0.0  0.0  0.021  0.19   1.60
# galactose       8789.0  0.004852  0.078666  0.0  0.0  0.000  0.00   5.62
# maltose         8789.0  0.071506  0.439321  0.0  0.0  0.000  0.00  10.04

# %%
nutrition3_stats[nutrition3_stats["max"] < 0.1]
# Out:
# Empty DataFrame
# Columns: [count, mean, std, min, 25%, 50%, 75%, max]
# Index: []

# %%
# Well, it seems like columns where actually ok and with info

# %%
nutrition3.head()
# Out:
#                  total_fat  saturated_fat  cholesterol  sodium  choline  \
# name
# Cornstarch             0.1            NaN          0.0     9.0      0.4
# Nuts, pecans          72.0            6.2          0.0     0.0     40.5
# Eggplant, raw          0.2            NaN          0.0     2.0      6.9
# Teff, uncooked         2.4            0.4          0.0    12.0     13.1
# Sherbet, orange        2.0            1.2          1.0    46.0      7.7
#
#                  folate  folic_acid  niacin  pantothenic_acid  riboflavin  \
# name
# Cornstarch          0.0         0.0   0.000             0.000       0.000
# Nuts, pecans       22.0         0.0   1.167             0.863       0.130
# Eggplant, raw      22.0         0.0   0.649             0.281       0.037
# Teff, uncooked      0.0         0.0   3.363             0.942       0.270
# Sherbet, orange     4.0         0.0   0.063             0.224       0.097
#
#                  ...    fat  saturated_fatty_acids  \
# name             ...
# Cornstarch       ...   0.05                  0.009
# Nuts, pecans     ...  71.97                  6.180
# Eggplant, raw    ...   0.18                  0.034
# Teff, uncooked   ...   2.38                  0.449
# Sherbet, orange  ...   2.00                  1.160
#
#                  monounsaturated_fatty_acids  polyunsaturated_fatty_acids  \
# name
# Cornstarch                             0.016                        0.025
# Nuts, pecans                          40.801                       21.614
# Eggplant, raw                          0.016                        0.076
# Teff, uncooked                         0.589                        1.071
# Sherbet, orange                        0.530                        0.080
#
#                  fatty_acids_total_trans  alcohol   ash  caffeine  \
# name
# Cornstarch                           0.0      0.0  0.09       0.0
# Nuts, pecans                         0.0      0.0  1.49       0.0
# Eggplant, raw                        0.0      0.0  0.66       0.0
# Teff, uncooked                       0.0      0.0  2.37       0.0
# Sherbet, orange                      1.0      0.0  0.40       0.0
#
#                  theobromine  water
# name
# Cornstarch               0.0   8.32
# Nuts, pecans             0.0   3.52
# Eggplant, raw            0.0  92.30
# Teff, uncooked           0.0   8.82
# Sherbet, orange          0.0  66.10
#
# [5 rows x 72 columns]

# %%
# Let's start plotting
sns.distplot(nutrition3["total_fat"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_fat', ylabel='Density'>

# %%
for column in nutrition3.columns[:5]:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 6))
    sns.histplot(nutrition3[column], bins = 50, ax = ax1)
    sns.boxplot(x = column, data = nutrition3, ax = ax2)

# %%
nutrition3[nutrition3["carbohydrate"] > 0][["total_fat", "protein", "carbohydrate", "fiber"]].sort_values(by = "protein", ascending = False).head(20)
# Out:
#                                                     total_fat  protein  \
# name
# Soy protein isolate, potassium type                       0.5    88.32
# Egg, glucose reduced, stabilized, dried, white            0.3    84.08
# Egg, glucose reduced, stabilized, powder, dried...        0.0    82.40
# Egg, dried, white                                         0.0    81.10
# Beverages, Protein powder whey based                      1.6    78.13
# Egg, glucose reduced, stabilized, flakes, dried...        0.0    76.92
# Vital wheat gluten                                        1.9    75.16
# Beverages, EAS whey protein powder, ABBOTT                5.1    66.67
# Soy protein concentrate, produced by acid wash            0.5    63.63
# Soy protein concentrate, produced by alcohol ex...        0.5    63.63
# Fish, dry (Alaska Native), Pacific, herring eggs          6.6    60.40
# Beverages, Whey protein powder isolate                    1.2    58.14
# Snacks, barbecue-flavor, pork skins                      32.0    57.90
# Seaweed, dried, spirulina                                 7.7    57.47
# Beverages, Protein powder soy based                       5.6    55.56
# Egg substitute, powder                                   13.0    55.50
# Gelatin desserts, vitamin C, sodium, potassium,...        0.0    55.30
# Gelatin desserts, no added sodium, with asparta...        0.0    55.30
# Beverages, powder, high protein, nutritional sh...       11.0    53.57
# Tofu, dried-frozen (koyadofu)                            30.0    52.47
#
#                                                     carbohydrate  fiber
# name
# Soy protein isolate, potassium type                         2.59    0.0
# Egg, glucose reduced, stabilized, dried, white              4.51    0.0
# Egg, glucose reduced, stabilized, powder, dried...          4.47    0.0
# Egg, dried, white                                           7.80    0.0
# Beverages, Protein powder whey based                        6.25    3.1
# Egg, glucose reduced, stabilized, flakes, dried...          4.17    0.0
# Vital wheat gluten                                         13.79    0.6
# Beverages, EAS whey protein powder, ABBOTT                 17.95    0.0
# Soy protein concentrate, produced by acid wash             25.41    5.5
# Soy protein concentrate, produced by alcohol ex...         25.41    5.5
# Fish, dry (Alaska Native), Pacific, herring eggs            2.80    0.0
# Beverages, Whey protein powder isolate                     29.07    0.0
# Snacks, barbecue-flavor, pork skins                         1.60    0.0
# Seaweed, dried, spirulina                                  23.90    3.6
# Beverages, Protein powder soy based                        28.89    6.7
# Egg substitute, powder                                     21.80    0.0
# Gelatin desserts, vitamin C, sodium, potassium,...         33.30    0.0
# Gelatin desserts, no added sodium, with asparta...         33.30    0.0
# Beverages, powder, high protein, nutritional sh...         20.38    0.0
# Tofu, dried-frozen (koyadofu)                              10.03    7.2

# %%
nutrition3[(nutrition3["protein"] > 30) & (nutrition3["carbohydrate"] > 5)][["total_fat", "protein", "carbohydrate", "fiber"]].sort_values(by = "protein", ascending = False).head(60)
# Out:
#                                                     total_fat  protein  \
# name
# Egg, dried, white                                         0.0    81.10
# Beverages, Protein powder whey based                      1.6    78.13
# Vital wheat gluten                                        1.9    75.16
# Beverages, EAS whey protein powder, ABBOTT                5.1    66.67
# Soy protein concentrate, produced by alcohol ex...        0.5    63.63
# Soy protein concentrate, produced by acid wash            0.5    63.63
# Beverages, Whey protein powder isolate                    1.2    58.14
# Seaweed, dried, spirulina                                 7.7    57.47
# Beverages, Protein powder soy based                       5.6    55.56
# Egg substitute, powder                                   13.0    55.50
# Gelatin desserts, no added sodium, with asparta...        0.0    55.30
# Gelatin desserts, vitamin C, sodium, potassium,...        0.0    55.30
# Beverages, powder, high protein, nutritional sh...       11.0    53.57
# Tofu, dried-frozen (koyadofu)                            30.0    52.47
# Tofu, prepared with calcium sulfate, dried-froz...       30.0    52.43
# Peanut flour, defatted                                    0.6    52.20
# Soy flour, defatted                                       1.2    51.46
# Seeds, low-fat, sesame flour                              1.8    50.14
# Protein supplement, powder, Muscle Milk Light, ...       12.0    50.00
# Seeds, low fat (glandless), cottonseed flour              1.4    49.83
# Soy flour, low-fat                                        8.9    49.81
# Soy meal, raw, defatted                                   2.4    49.20
# Seeds, partially defatted (glandless), cottonse...        4.8    49.10
# Seeds, partially defatted, sunflower seed flour           1.6    48.06
# Mollusks, moist heat, cooked, unspecified, whelk          0.8    47.68
# Beverages, EAS soy protein powder, ABBOTT                 3.6    47.62
# Protein supplement, powder, Muscle Milk, milk b...       17.0    45.71
# Soybeans, dry roasted, mature seeds                      22.0    43.32
# Meat extender                                             3.0    41.71
# Seeds, partially defatted (glandless), cottonse...        6.2    40.96
# Leavening agents, active dry, baker's, yeast              7.6    40.44
# Seeds, partially defatted, sesame flour                  12.0    40.32
# Parmesan cheese topping, fat free                         5.0    40.00
# Soybeans, no salt added, roasted, mature seeds           25.0    38.55
# Soybeans, salted, roasted, mature seeds                  25.0    38.55
# Soy flour, roasted, full-fat                             22.0    38.09
# Soy flour, raw, full-fat                                 21.0    37.81
# Soybeans, raw, mature seeds                              20.0    36.49
# Lupins, raw, mature seeds                                 9.7    36.17
# Milk, without added vitamin A and vitamin D, re...        0.8    36.16
# Milk, with added vitamin A and vitamin D, regul...        0.8    36.16
# Beverage, not reconstituted, sugar-free, chocol...        5.1    35.80
# Seeds, partially defatted, safflower seed meal            2.4    35.62
# Egg Mix, USDA Commodity                                  35.0    35.60
# Milk, calcium reduced, nonfat, dry                        0.2    35.50
# Beverages, KELLOGG'S SPECIAL K20 protein powder           0.6    35.20
# Milk, with added vitamin A and vitamin D, insta...        0.7    35.10
# Milk, without added vitamin A and vitamin D, in...        0.7    35.10
# Milk, dried, buttermilk                                   5.8    34.30
# Peanut flour, low fat                                    22.0    33.80
# Snacks, chopped and formed, beef jerky                   26.0    33.20
# Seeds, roasted (glandless), cottonseed kernels           36.0    32.59
# Cheese, nonfat or fat free, cheddar                       0.0    32.14
# Bacon bits, meatless                                     26.0    32.00
# Seeds, hulled, hemp seed                                 49.0    31.56
# Cereals ready-to-eat, Regular, KRETSCHMER Wheat...        9.6    31.43
# Parsley, freeze-dried                                     5.2    31.30
# Cereals ready-to-eat, SPECIAL K Protein Plus, K...        2.6    31.20
# Seeds, high-fat, sesame flour                            37.0    30.78
# Formulated Bar, SOUTH BEACH protein bar                  15.0    30.34
#
#                                                     carbohydrate  fiber
# name
# Egg, dried, white                                           7.80    0.0
# Beverages, Protein powder whey based                        6.25    3.1
# Vital wheat gluten                                         13.79    0.6
# Beverages, EAS whey protein powder, ABBOTT                 17.95    0.0
# Soy protein concentrate, produced by alcohol ex...         25.41    5.5
# Soy protein concentrate, produced by acid wash             25.41    5.5
# Beverages, Whey protein powder isolate                     29.07    0.0
# Seaweed, dried, spirulina                                  23.90    3.6
# Beverages, Protein powder soy based                        28.89    6.7
# Egg substitute, powder                                     21.80    0.0
# Gelatin desserts, no added sodium, with asparta...         33.30    0.0
# Gelatin desserts, vitamin C, sodium, potassium,...         33.30    0.0
# Beverages, powder, high protein, nutritional sh...         20.38    0.0
# Tofu, dried-frozen (koyadofu)                              10.03    7.2
# Tofu, prepared with calcium sulfate, dried-froz...          8.30    1.2
# Peanut flour, defatted                                     34.70   15.8
# Soy flour, defatted                                        33.92   17.5
# Seeds, low-fat, sesame flour                               35.51    0.0
# Protein supplement, powder, Muscle Milk Light, ...         22.00    2.0
# Seeds, low fat (glandless), cottonseed flour               36.10    0.0
# Soy flour, low-fat                                         30.63   16.0
# Soy meal, raw, defatted                                    35.89    0.0
# Seeds, partially defatted (glandless), cottonse...         38.43    0.0
# Seeds, partially defatted, sunflower seed flour            35.83    5.2
# Mollusks, moist heat, cooked, unspecified, whelk           15.52    0.0
# Beverages, EAS soy protein powder, ABBOTT                  43.94    0.0
# Protein supplement, powder, Muscle Milk, milk b...         18.50    7.1
# Soybeans, dry roasted, mature seeds                        28.98    8.1
# Meat extender                                              34.71   17.5
# Seeds, partially defatted (glandless), cottonse...         40.54    3.0
# Leavening agents, active dry, baker's, yeast               41.22   26.9
# Seeds, partially defatted, sesame flour                    35.14    0.0
# Parmesan cheese topping, fat free                          40.00    0.0
# Soybeans, no salt added, roasted, mature seeds             30.22   17.7
# Soybeans, salted, roasted, mature seeds                    30.22   17.7
# Soy flour, roasted, full-fat                               30.38    9.7
# Soy flour, raw, full-fat                                   31.92    9.6
# Soybeans, raw, mature seeds                                30.16    9.3
# Lupins, raw, mature seeds                                  40.37   18.9
# Milk, without added vitamin A and vitamin D, re...         51.98    0.0
# Milk, with added vitamin A and vitamin D, regul...         51.98    0.0
# Beverage, not reconstituted, sugar-free, chocol...         41.00    2.0
# Seeds, partially defatted, safflower seed meal             48.73    0.0
# Egg Mix, USDA Commodity                                    23.97    0.0
# Milk, calcium reduced, nonfat, dry                         51.80    0.0
# Beverages, KELLOGG'S SPECIAL K20 protein powder            58.40   37.5
# Milk, with added vitamin A and vitamin D, insta...         52.19    0.0
# Milk, without added vitamin A and vitamin D, in...         52.19    0.0
# Milk, dried, buttermilk                                    49.00    0.0
# Peanut flour, low fat                                      31.27   15.8
# Snacks, chopped and formed, beef jerky                     11.00    1.8
# Seeds, roasted (glandless), cottonseed kernels             21.90    5.5
# Cheese, nonfat or fat free, cheddar                         7.14    0.0
# Bacon bits, meatless                                       28.60   10.2
# Seeds, hulled, hemp seed                                    8.67    4.0
# Cereals ready-to-eat, Regular, KRETSCHMER Wheat...         49.38   11.9
# Parsley, freeze-dried                                      42.38   32.7
# Cereals ready-to-eat, SPECIAL K Protein Plus, K...         60.60    8.3
# Seeds, high-fat, sesame flour                              26.62    0.0
# Formulated Bar, SOUTH BEACH protein bar                    38.40    7.3

# %%
# I can see from the data that it also includes beverages, shakes, supplements, and so on...
# As I'm actually interested in the raw food, I'll do some cleaning here

# %%
nutrition3["supplement"] = nutrition3.index.str.contains("supplement")
nutrition3.head()
# Out:
#                  total_fat  saturated_fat  cholesterol  sodium  choline  \
# name
# Cornstarch             0.1            NaN          0.0     9.0      0.4
# Nuts, pecans          72.0            6.2          0.0     0.0     40.5
# Eggplant, raw          0.2            NaN          0.0     2.0      6.9
# Teff, uncooked         2.4            0.4          0.0    12.0     13.1
# Sherbet, orange        2.0            1.2          1.0    46.0      7.7
#
#                  folate  folic_acid  niacin  pantothenic_acid  riboflavin  \
# name
# Cornstarch          0.0         0.0   0.000             0.000       0.000
# Nuts, pecans       22.0         0.0   1.167             0.863       0.130
# Eggplant, raw      22.0         0.0   0.649             0.281       0.037
# Teff, uncooked      0.0         0.0   3.363             0.942       0.270
# Sherbet, orange     4.0         0.0   0.063             0.224       0.097
#
#                  ...  saturated_fatty_acids  monounsaturated_fatty_acids  \
# name             ...
# Cornstarch       ...                  0.009                        0.016
# Nuts, pecans     ...                  6.180                       40.801
# Eggplant, raw    ...                  0.034                        0.016
# Teff, uncooked   ...                  0.449                        0.589
# Sherbet, orange  ...                  1.160                        0.530
#
#                  polyunsaturated_fatty_acids  fatty_acids_total_trans  \
# name
# Cornstarch                             0.025                      0.0
# Nuts, pecans                          21.614                      0.0
# Eggplant, raw                          0.076                      0.0
# Teff, uncooked                         1.071                      0.0
# Sherbet, orange                        0.080                      1.0
#
#                  alcohol   ash  caffeine  theobromine  water  supplement
# name
# Cornstarch           0.0  0.09       0.0          0.0   8.32       False
# Nuts, pecans         0.0  1.49       0.0          0.0   3.52       False
# Eggplant, raw        0.0  0.66       0.0          0.0  92.30       False
# Teff, uncooked       0.0  2.37       0.0          0.0   8.82       False
# Sherbet, orange      0.0  0.40       0.0          0.0  66.10       False
#
# [5 rows x 73 columns]

# %%
nutrition3[nutrition3.index.str.contains("supplement")]
# Out:
#                                                     total_fat  saturated_fat  \
# name
# Protein supplement, powder, Muscle Milk, milk b...       17.0            1.6
# Protein supplement, powder, Muscle Milk Light, ...       12.0            1.1
# Beverages, peanut flavor, canned, Meal suppleme...        3.1            0.6
# Nutritional supplement for people with diabetes...        3.1            0.2
#
#                                                     cholesterol  sodium  \
# name
# Protein supplement, powder, Muscle Milk, milk b...         21.0   329.0
# Protein supplement, powder, Muscle Milk Light, ...         10.0   250.0
# Beverages, peanut flavor, canned, Meal suppleme...          0.0    54.0
# Nutritional supplement for people with diabetes...          2.0    92.0
#
#                                                     choline  folate  \
# name
# Protein supplement, powder, Muscle Milk, milk b...     81.6   200.0
# Protein supplement, powder, Muscle Milk Light, ...     81.6   280.0
# Beverages, peanut flavor, canned, Meal suppleme...      0.0     0.0
# Nutritional supplement for people with diabetes...     60.5    44.0
#
#                                                     folic_acid  niacin  \
# name
# Protein supplement, powder, Muscle Milk, milk b...       200.0  10.000
# Protein supplement, powder, Muscle Milk Light, ...       280.0  14.000
# Beverages, peanut flavor, canned, Meal suppleme...         0.0   6.600
# Nutritional supplement for people with diabetes...        44.0   2.201
#
#                                                     pantothenic_acid  \
# name
# Protein supplement, powder, Muscle Milk, milk b...             5.714
# Protein supplement, powder, Muscle Milk Light, ...             8.000
# Beverages, peanut flavor, canned, Meal suppleme...             1.700
# Nutritional supplement for people with diabetes...             1.100
#
#                                                     riboflavin  ...  \
# name                                                            ...
# Protein supplement, powder, Muscle Milk, milk b...       0.857  ...
# Protein supplement, powder, Muscle Milk Light, ...       1.200  ...
# Beverages, peanut flavor, canned, Meal suppleme...       1.300  ...
# Nutritional supplement for people with diabetes...       0.187  ...
#
#                                                     saturated_fatty_acids  \
# name
# Protein supplement, powder, Muscle Milk, milk b...                  1.553
# Protein supplement, powder, Muscle Milk Light, ...                  1.087
# Beverages, peanut flavor, canned, Meal suppleme...                  0.571
# Nutritional supplement for people with diabetes...                  0.232
#
#                                                     monounsaturated_fatty_acids  \
# name
# Protein supplement, powder, Muscle Milk, milk b...                       12.105
# Protein supplement, powder, Muscle Milk Light, ...                        8.474
# Beverages, peanut flavor, canned, Meal suppleme...                        1.922
# Nutritional supplement for people with diabetes...                        2.318
#
#                                                     polyunsaturated_fatty_acids  \
# name
# Protein supplement, powder, Muscle Milk, milk b...                        1.770
# Protein supplement, powder, Muscle Milk Light, ...                        1.239
# Beverages, peanut flavor, canned, Meal suppleme...                        0.178
# Nutritional supplement for people with diabetes...                        0.395
#
#                                                     fatty_acids_total_trans  \
# name
# Protein supplement, powder, Muscle Milk, milk b...                     21.0
# Protein supplement, powder, Muscle Milk Light, ...                     10.0
# Beverages, peanut flavor, canned, Meal suppleme...                      0.0
# Nutritional supplement for people with diabetes...                      2.0
#
#                                                     alcohol   ash  caffeine  \
# name
# Protein supplement, powder, Muscle Milk, milk b...      0.0  3.65       0.0
# Protein supplement, powder, Muscle Milk Light, ...      0.0  4.00       0.0
# Beverages, peanut flavor, canned, Meal suppleme...      0.0  0.90       0.0
# Nutritional supplement for people with diabetes...      0.0  0.90       2.0
#
#                                                     theobromine  water  \
# name
# Protein supplement, powder, Muscle Milk, milk b...          0.0  15.00
# Protein supplement, powder, Muscle Milk Light, ...          0.0  12.00
# Beverages, peanut flavor, canned, Meal suppleme...          0.0  77.79
# Nutritional supplement for people with diabetes...         23.0  79.74
#
#                                                     supplement
# name
# Protein supplement, powder, Muscle Milk, milk b...        True
# Protein supplement, powder, Muscle Milk Light, ...        True
# Beverages, peanut flavor, canned, Meal suppleme...        True
# Nutritional supplement for people with diabetes...        True
#
# [4 rows x 73 columns]

# %%
nutrition3["Beverages"] = nutrition3.index.str.contains("Beverages")

# %%
nutrition3[nutrition3["Beverages"] == True].index
# Out:
# Index(['Beverages, orange, carbonated', 'Beverages, hard cider, AMBER',
#        'Beverages, powder, Cocoa mix', 'Beverages, AMP, Energy drink',
#        'Beverages, well, tap, water', 'Beverages, powder, Lemonade',
#        'Beverages, chocolate syrup', 'Beverages, cola, ZEVIA',
#        'Beverages, Cran Grape, OCEAN SPRAY',
#        'Beverages, tonic water, carbonated',
#        ...
#        'Beverages, vitamin A and vitamin D,  added calcium, Ready-to-drink, flavored and sweetened, reduced fat, milk beverage',
#        'Beverages, fortified with vitamins B6 and B12, sugar-free with guarana, energy drink, NOS Zero, THE COCA-COLA COMPANY',
#        'Beverages, vitamins B6 and B12, pantothenic acid, niacin, with added caffeine, sugar free, RED BULL, Energy drink',
#        'Beverages, prepared with water and ice, powder, with aspartame, reduced calorie, chocolate, dairy drink mix',
#        'Beverages, added calcium, high vitamin C, greater than 3% fruit juice, reduced sugar, Fruit flavored drink',
#        'Beverages, prepared with whole milk, with added nutrients, powder, chocolate-flavor beverage mix for milk',
#        'Beverages, added vitamin C, with low-calorie sweetener, reduced calorie, Vegetable and fruit juice drink',
#        'Beverages, frozen concentrate. Not manufactured anymore., with pulp, breakfast type, Orange-flavor drink',
#        'Beverages, mineral bottled water, naturally sparkling, GEROLSTEINER BRUNNEN GmbH & Co. KG (Gerolsteiner)',
#        'Beverages, prepared with water, frozen concentrate, with juice and pulp, breakfast type, Orange drink'],
#       dtype='object', name='name', length=282)

# %%
nutrition3["total_fat"].sort_values(ascending = False)
# Out:
# name
# Oil, walnut                                    100.0
# Oil, whale (Alaska Native), beluga             100.0
# Oil, (approx. 65%), linoleic, sunflower        100.0
# Oil, salad or cooking, peanut                  100.0
# Oil, linoleic (less than 60%), sunflower       100.0
#                                                ...
# Bread, toasted, sprouted, wheat                  0.0
# Carbonated beverage, cream soda                  0.0
# Beverages, Malt liquor beverage                  0.0
# Alcoholic Beverage, Syrah, red, table, wine      0.0
# Alcoholic beverages, rose, wine                  0.0
# Name: total_fat, Length: 8789, dtype: float64

# %%
macros = ["protein", "carbohydrate", "fat", "alcohol"]
micros = ["vitamin_a", "vitamin_b12", "vitamin_b6", "vitamin_c", "vitamin_e", "magnesium", "zink", "calcium", "irom", "potassium"]
others = ["fiber", "sugars", "cholesterol"]
fats = ["total_fat", "saturated_fat", "saturated_fatty_acids", "monounsaturated_fatty_acids", "polyunsaturated_fatty_acids"]

l = [macros, micros, others, fats]
full_column_filter = []

for i in l:
    full_column_filter.extend(i)

# %%
full_column_filter
# Out:
# ['protein',
#  'carbohydrate',
#  'fat',
#  'alcohol',
#  'vitamin_a',
#  'vitamin_b12',
#  'vitamin_b6',
#  'vitamin_c',
#  'vitamin_e',
#  'magnesium',
#  'zink',
#  'calcium',
#  'irom',
#  'potassium',
#  'fiber',
#  'sugars',
#  'cholesterol',
#  'total_fat',
#  'saturated_fat',
#  'saturated_fatty_acids',
#  'monounsaturated_fatty_acids',
#  'polyunsaturated_fatty_acids']

# %%
others
# Out:
# ['fiber', 'sugars', 'cholesterol']
