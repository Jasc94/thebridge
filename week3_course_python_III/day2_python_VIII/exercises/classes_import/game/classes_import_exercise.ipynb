# %% [markdown]
# ## 1
#
# Crea un archivo 'ClaseHumano.py' en la carpeta 'objects' que contenga una clase:
#
# * 'Humano' que tiene:
#     - Un atributo 'ojos' que por defecto es 2
#     - Un atributo 'piernas' que por defecto es 2
#     - Un atributo 'dientes' que por defecto es 32
#     - Un atributo 'nombre'
#     - Un atributo 'armadura'
#     - Un atributo 'nivel'
#     - Un atributo 'ataque'
#     - Un atributo 'salud' que por defecto es 100
#     - Una función  llamada 'atacar' que recibe un argumento 'orco' que representa otra clase ('Orco'). Esta función resta a la vida del 'Orco' el ataque de 'Humano' menos la armadura de 'Orco'. Al final, muestra por pantalla la vida del 'Orco'
#     - Una función no_vivo que retorna True si la vida del 'Humano' es igual o inferior a 0, False en otro caso.
#     - Una función que muestre por pantalla todos los atributos actuales de 'Humano' concatenados con un String representando el nombre del atributo que se muestra. Ejemplo: "Nombre: Ataulfo | dientes: 32 | salud: 100 | ..."
#
# Crea un archivo 'ClaseOrco.py' en la carpeta 'objects' que contenga una clase:
#
# * 'Orco' que tiene:
#     - Un atributo 'ojos' que por defecto es 2
#     - Un atributo 'piernas' que por defecto es 2
#     - Un atributo 'dientes' que por defecto es 56
#     - Un atributo 'nombre'
#     - Un atributo 'armadura'
#     - Un atributo 'nivel'
#     - Un atributo 'ataque'
#     - Un atributo 'salud' que por defecto es 100
#     - Una función  llamada 'atacar' que recibe un argumento 'humano' que representa otra clase ('Humano'). Esta función resta a la vida del 'Humano' el ataque de 'Orco' menos la armadura de 'Humano'. Al final, muestra por pantalla la vida del 'Humano'
#     - Una función no_vivo que retorna True si la vida del 'Humano' es igual o inferior a 0, False en otro caso.
#     - Una función que muestre por pantalla todos los atributos actuales de 'Orco' concatenados con un String representando el nombre del atributo que se muestra. Ejemplo: "Nombre: Graug | dientes: 56 | salud: 100 | ..."

# %% [markdown]
# ## 2
#
# Desde aquí, importa las clases del ejercicio 1 (tendrás que utilizar sys.path para poder importar los archivos/módulos/librerías/ficheros). Crea una instancia de Humano/a y otra de Orco/a:
#
# * La clase Humano/a ha de inicializarse con los siguientes valores:
#     - nombre: tu nombre
#     - nivel: tu edad
#     - armadura: un número Entero que sea un décimo de tu nivel redondeado hacia abajo
#     - ataque: un número Entero que sea un quinto de tu nivel redondeado hacia abajo
#     - Todo lo demás por defecto.
#
# * La clase Orco/a ha de inicializarse con los siguientes valores:
#     - nombre: el nombre de tu compañero/a
#     - nivel: su edad
#     - armadura: un número Entero que sea un quinceavo de su nivel redondeado hacia arriba
#     - ataque: un número Entero que sea un sexto de su nivel redondeado hacia arriba
#     - Todo lo demás por defecto.

# %%
import sys
import os

# I get the path I need to access the corresponding folder
path = os.getcwd()
path = os.path.dirname(path)

# I append the path to sys.path
sys.path.append(path)
sys.path
# Out:
# ['/Users/jonathansuarezcaceres/Downloads/1_DataScience/TheBridge/thebridge/week3_course_python_III/day2_python_VIII/exercises/classes_import/game',
#  '/Users/jonathansuarezcaceres/.vscode/extensions/ms-toolsai.jupyter-2021.5.745244803/pythonFiles',
#  '/Users/jonathansuarezcaceres/.vscode/extensions/ms-toolsai.jupyter-2021.5.745244803/pythonFiles',
#  '/Users/jonathansuarezcaceres/.vscode/extensions/ms-toolsai.jupyter-2021.5.745244803/pythonFiles/lib/python',
#  '/opt/anaconda3/lib/python38.zip',
#  '/opt/anaconda3/lib/python3.8',
#  '/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/opt/anaconda3/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/jonathansuarezcaceres/.ipython',
#  '/Users/jonathansuarezcaceres/Downloads/1_DataScience/TheBridge/thebridge/week3_course_python_III/day2_python_VIII/exercises/classes_import']

# %%
# I import the module
import objects.ClaseHumano as ch

# For my classes: Name, Age, Armour, Level, Attack
jonhy = ch.Humano('Jonhy', 27 // 10, 27, 27 // 5)
marina = ch.Orco('Marina', round(25 / 15), 25, round(25 / 6))

print(jonhy.atributos())
print(marina.atributos())
# Out:
# Nombre: Jonhy | Armadura: 2 | Nivel: 27 | Ataque: 5 | Ojos: 2 | Piernas: 2 | Dientes: 32 | Salud: 100
# Nombre: Marina | Armadura: 2 | Nivel: 25 | Ataque: 4 | Ojos: 2 | Piernas: 2 | Dientes: 56 | Salud: 100

# %% [markdown]
# ## 3
#
# Crea un bucle infinito que espere en cada turno(Iteración) 1 segundo. Para ello has de utilizar la función 'sleep(1)' de la librería time. En cada uno de los turnos debe ocurrir lo siguiente:
#
# - Que se muestre por pantalla el número del turno que se lleva empezando desde 1.
# - Que se ataquen las instancias. Para ello, has de llamar a la función 'atacar' de cada una de las instancias.
# - Comprobar si una instancia no está viva con la función correspondiente. Si una instancia no está viva, mostrar por pantalla que una de ellas ha perdido y la otra ha ganado. Terminar el juego aquí.
# - Mostrar al finalizar el turno una barra divisoria para diferenciar un turno del siguiente.
#
# Hay que tener en cuenta:
#
# - Una instancia no puede atacar a la otra si no está viva.
# - Empieza primero la instancia que tiene menos nivel.

# %%
# Ejecutar siempre la celda anterior
import time

count = 1
while not jonhy.no_vivo() and not marina.no_vivo():

    print(f'This is the round {count}')
    # We start the game with the one with lower level
    print('Marina attacks Jonhy', marina.atacar(jonhy), '\n')
    print('Jonhy attacks Marina', jonhy.atacar(marina), '\n')

    print('End of the round\n', '-' * 15)

    count += 1
    time.sleep(0.5)

if jonhy.salud > marina.salud:
    print('Jonhy won\n')
else:
    print('Marina won\n')

print(f'End result: Marina\'s remaining life {marina.salud} |  Marina\'s remaining life {jonhy.salud}')
# Out:
# This is the round 1
# Marina attacks Jonhy 98
#
# Jonhy attacks Marina 97
#
# End of the round
#  ---------------
# This is the round 2
# Marina attacks Jonhy 96
#
# Jonhy attacks Marina 94
#
# End of the round
#  ---------------
# This is the round 3
# Marina attacks Jonhy 94
#
# Jonhy attacks Marina 91
#
# End of the round
#  ---------------
# This is the round 4
# Marina attacks Jonhy 92
#
# Jonhy attacks Marina 88
#
# End of the round
#  ---------------
# This is the round 5
# Marina attacks Jonhy 90
#
# Jonhy attacks Marina 85
#
# End of the round
#  ---------------
# This is the round 6
# Marina attacks Jonhy 88
#
# Jonhy attacks Marina 82
#
# End of the round
#  ---------------
# This is the round 7
# Marina attacks Jonhy 86
#
# Jonhy attacks Marina 79
#
# End of the round
#  ---------------
# This is the round 8
# Marina attacks Jonhy 84
#
# Jonhy attacks Marina 76
#
# End of the round
#  ---------------
# This is the round 9
# Marina attacks Jonhy 82
#
# Jonhy attacks Marina 73
#
# End of the round
#  ---------------
# This is the round 10
# Marina attacks Jonhy 80
#
# Jonhy attacks Marina 70
#
# End of the round
#  ---------------
# This is the round 11
# Marina attacks Jonhy 78
#
# Jonhy attacks Marina 67
#
# End of the round
#  ---------------
# This is the round 12
# Marina attacks Jonhy 76
#
# Jonhy attacks Marina 64
#
# End of the round
#  ---------------
# This is the round 13
# Marina attacks Jonhy 74
#
# Jonhy attacks Marina 61
#
# End of the round
#  ---------------
# This is the round 14
# Marina attacks Jonhy 72
#
# Jonhy attacks Marina 58
#
# End of the round
#  ---------------
# This is the round 15
# Marina attacks Jonhy 70
#
# Jonhy attacks Marina 55
#
# End of the round
#  ---------------
# This is the round 16
# Marina attacks Jonhy 68
#
# Jonhy attacks Marina 52
#
# End of the round
#  ---------------
# This is the round 17
# Marina attacks Jonhy 66
#
# Jonhy attacks Marina 49
#
# End of the round
#  ---------------
# This is the round 18
# Marina attacks Jonhy 64
#
# Jonhy attacks Marina 46
#
# End of the round
#  ---------------
# This is the round 19
# Marina attacks Jonhy 62
#
# Jonhy attacks Marina 43
#
# End of the round
#  ---------------
# This is the round 20
# Marina attacks Jonhy 60
#
# Jonhy attacks Marina 40
#
# End of the round
#  ---------------
# This is the round 21
# Marina attacks Jonhy 58
#
# Jonhy attacks Marina 37
#
# End of the round
#  ---------------
# This is the round 22
# Marina attacks Jonhy 56
#
# Jonhy attacks Marina 34
#
# End of the round
#  ---------------
# This is the round 23
# Marina attacks Jonhy 54
#
# Jonhy attacks Marina 31
#
# End of the round
#  ---------------
# This is the round 24
# Marina attacks Jonhy 52
#
# Jonhy attacks Marina 28
#
# End of the round
#  ---------------
# This is the round 25
# Marina attacks Jonhy 50
#
# Jonhy attacks Marina 25
#
# End of the round
#  ---------------
# This is the round 26
# Marina attacks Jonhy 48
#
# Jonhy attacks Marina 22
#
# End of the round
#  ---------------
# This is the round 27
# Marina attacks Jonhy 46
#
# Jonhy attacks Marina 19
#
# End of the round
#  ---------------
# This is the round 28
# Marina attacks Jonhy 44
#
# Jonhy attacks Marina 16
#
# End of the round
#  ---------------
# This is the round 29
# Marina attacks Jonhy 42
#
# Jonhy attacks Marina 13
#
# End of the round
#  ---------------
# This is the round 30
# Marina attacks Jonhy 40
#
# Jonhy attacks Marina 10
#
# End of the round
#  ---------------
# This is the round 31
# Marina attacks Jonhy 38
#
# Jonhy attacks Marina 7
#
# End of the round
#  ---------------
# This is the round 32
# Marina attacks Jonhy 36
#
# Jonhy attacks Marina 4
#
# End of the round
#  ---------------
# This is the round 33
# Marina attacks Jonhy 34
#
# Jonhy attacks Marina 1
#
# End of the round
#  ---------------
# This is the round 34
# Marina attacks Jonhy 32
#
# Jonhy attacks Marina -2
#
# End of the round
#  ---------------
# Jonhy won
#
# End result: Marina's remaining life -2 |  Marina's remaining life 32
